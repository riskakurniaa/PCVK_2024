# %% [markdown]
# <a href="https://colab.research.google.com/github/riskakurniaa/PCVK_Ganjil_2024/blob/main/Modul1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama  : **Riska Kurnia Triwulandari**
# Kelas : **3A**
# NIM   : **2241720039**

# %% [markdown]
# **Step 1**

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# **Step 2**
# Membaca image dari URLs - Read Image from URLs

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://avatars.githubusercontent.com/u/120325374?v=4"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls:
  image = io.imread(url)                          # read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) # resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  # convert color to RGB
  final_frame = cv.hconcat((image, image_2))      # concatenate image
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=460x230>

# %% [markdown]
# **Step 3**
# Melihat ukuran file image

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("Resolusi image: tinggi x lebar = ", tinggi, " x ", lebar)
cv2_imshow(image_2)
# Out:
# Resolusi image: tinggi x lebar =  230  x  230
# <PIL.Image.Image image mode=RGB size=230x230>

# %% [markdown]
# **Step 4**
# Mengakses pixel dengan memberi garis diagonal menyilang

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal di tengah image
for y in range(lebar):
  image_3[int((tinggi)/2), y] = [255, 255, 255]

# menampilkan image
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=460x230>

# %% [markdown]
# ### 1. Mengapa pada modul praktikum ini eksekusi kode Python dilakukan menggunakan Google Colab?
# Google Colab mudah digunakan karena tidak memerlukan instalasi library satu per satu dan dapat langsung terhubung dengan repository GitHub. Sebagai platform berbasis cloud, Colab menghilangkan kebutuhan untuk mengunduh installer di komputer. Selain itu, Colab memberikan akses gratis ke GPU (Graphics Processing Unit), yang sangat berguna untuk mempercepat proses pengolahan gambar dan machine learning. Kita juga dapat dengan mudah berkolaborasi atau berbagi kode program, serta menyimpan proyek ke GitHub. Colab berbasis pada lingkungan Jupyter dan mendukung berbagai library untuk pemrosesan gambar, seperti OpenCV, TensorFlow, Keras, dan lainnya.
#
# ### 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
# - **numpy**: Digunakan untuk manipulasi array multidimensi (seperti matriks), operasi matematika, dan linear algebra.
# - **pandas**: Digunakan untuk membaca data dari berbagai format (CSV, Excel, dll.), membersihkan data, dan melakukan analisis statistik.
# - **cv2**: Menyediakan berbagai fungsi untuk membaca, menulis, mengubah, dan menganalisis gambar.
# - **cv2_imshow**: Untuk menampilkan hasil pemrosesan gambar secara visual.
# - **io**: Dalam konteks pemrosesan gambar, sering digunakan untuk membaca gambar dari file atau URL.
# - **transform**: Untuk berbagai teknik transformasi (misalnya, rotasi, scaling, shearing) yang diterapkan pada gambar untuk mengubah representasinya.
# - **image**: Library untuk manipulasi gambar.
# - **matplotlib.pylab**: Submodul dari Matplotlib, menyediakan fungsi-fungsi untuk membuat plot dan visualisasi data.
#
# ### 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut:
# ![image.png](data:image/png;base64,...)
# ###Apa kegunaan kode program tersebut? dan apa pengaruhnya jika tidak dilakukan?
# Kegunaan kode program tersebut adalah untuk meresize gambar agar berukuran setengah dari ukuran aslinya.
#
# - **image**: Ini adalah variabel yang berisi data gambar yang akan diubah ukurannya.
# - **(0,0)**: Parameter ini menentukan ukuran akhir gambar secara langsung (width, height). Namun, dalam kasus ini, parameter tersebut diatur ke (0,0), yang berarti ukuran spesifik tidak ditentukan, dan ukuran gambar akan ditentukan berdasarkan faktor skala `fx` dan `fy`.
# - **fx=0.5**: Ini adalah faktor skala untuk lebar (width) gambar. Dengan `fx=0.5`, lebar gambar akan dikurangi menjadi setengah dari ukuran aslinya.
# - **fy=0.5**: Ini adalah faktor skala untuk tinggi (height) gambar. Dengan `fy=0.5`, tinggi gambar akan dikurangi menjadi setengah dari ukuran aslinya.
#
# ### 4. Perhatikan potongan kode program berikut:
# ![image.png](data:image/png;base64,...)
# ###Apa kegunaan kode `[255,255,255]`? Jelaskan!
# Potongan kode tersebut merepresentasikan warna dalam format RGB (Red, Green, Blue) yang menunjukkan kode RGB untuk warna putih. Kegunaannya adalah untuk mengatur warna pixel pada koordinat tertentu, sehingga memberikan garis horizontal pada tengah gambar.
#
# ### 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
# Piksel adalah komponen dasar yang membentuk gambar digital, dan resolusi gambar menunjukkan seberapa banyak piksel yang ada dalam gambar tersebut. Semakin besar resolusi dari sebuah gambar, maka akan semakin banyak pula piksel yang menyusunnya, sehingga hasil gambar menjadi lebih detail dan berkualitas tinggi (HD). Sebaliknya, semakin kecil resolusi gambar, maka jumlah piksel yang membentuk gambar juga lebih sedikit, yang bisa menyebabkan gambar terlihat kurang tajam dan kurang detail.

# %% [markdown]
# E. TUGAS
# 1. Lakukan langkah-langkah praktikum seperti diatas
# 2. Buat garis vertikal dan garis menyilang diagonal pada image keluaran

# %%
# Membuat garis vertikal pada image keluaran
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis vertikal di tengah image (loop)
for y in range(tinggi):
  image_3[y, int(lebar/2)] = [255, 255, 255]

# menampilkan image
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
print('\n')

# Membuat garis menyilang diagonal pada image keluaran
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range(tinggi):
    x = int((lebar / tinggi) * y)
    image_3[y, x] = [255, 255, 255]

# diagonal dari kanan atas ke kiri bawah
for y in range(tinggi):
    x = int((lebar / tinggi) * (tinggi - y - 1))
    image_3[y, x] = [255, 255, 255]

# menampilkan image
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=460x230>
# <PIL.Image.Image image mode=RGB size=460x230>

# %% [markdown]
# 3. Buat garis horisontal berwarna putih dibagian tengah gambar dengan panjang
# tertentu

# %%
# Buat garis horisontal berwarna putih dibagian tengah gambar
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# membuat garis horizontal di tengah image (loop)
for y in range(75,175):
  image_3[int(tinggi/2), y] = [255, 255, 255]

# menampilkan image
final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=460x230>

# %% [markdown]
# 4. Buat kotak menggunakan kumpulan pixel warna putih di sembarang tempat dalam
# gambar

# %%
# Buat Kotak di gambar
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Membuat kotak digambar
for y in range (80,150):
  for x in range (75,150):
    image_3[x,y] = [255,255,255]

# Menggabungkan 2 gambar secara horizontal
final_frame = cv.hconcat((image_2, image_3))

# Menampilkan gambar gabungan
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=460x230>

# %% [markdown]
# Bentuk kelompok masing-masing terdiri dari 2-3 orang. tiap kelompok lakukan langkah berikut:
# 1. Akses file image lokal (KTP/SIM) dan tampilkan menggunakan OpenCV dan Matplotlib
# 2. Identifikasi kenapa menggunakan konversi warna BGR2RGB pada matplotlib dan tanpa
# konversi pada opencv
# 3. Tutup tiap bagian tertentu dari kartu identitas tersebut. Kelompok 1 tutup bagian nomor
# NIK dan nama. Kelompok 2 tutup bagian TTL dan Jenis Kelamin. Kelompok 3 tutup bagian
# Gol. Darah dan TTD. Kelompok 4 tutup bagian Alamat dan Kecamatan. Kelompok 5 tutup
# bagian Agama dan Status Kawin. Kelompok 6 tutup Pekerjaan dan kewarganegaraan.
# Kelompok 7 tutup bagian berlaku hingga dan foto. Kelompok 8 tutup bagian kabupaten
# dan tanggal dikeluarkan KTP yang ada dibagian bawah foto. Kelompok 9 tutup bagian
# nama propinsi dan kabupaten di bagian paling atas KTP. Kelompok 10 tutup bagian RT/RW
# dan Kel/desa. Tutup menggunakan 2 kotak warna yang berbeda. Tidak boleh
# menggunakan fungsi rectangle openCV, fungsi ini akan dipelajari pada pertemuan 2.

# %% [markdown]
# **Tugas Kelompok - Kelompok 6**

# %%
from google.colab import files
uploaded = files.upload()  # Pilih file untuk diunggah

import os
os.makedirs('/content/KTP', exist_ok=True)  # Membuat folder jika belum ada
# !mv /content/ktp.jpg /content/KTP/ktp.jpg  # Memindahkan file ke folder KTP
# Out:
#      <input type="file" id="files-9e4317b9-c66d-40ba-82ef-f57a56823bfa" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9e4317b9-c66d-40ba-82ef-f57a56823bfa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Membuat list untuk KTP
KTP = ["/content/KTP/ktp.jpg"]

# loop pada tiap ktp, beberapa image dapat disimpan pada list
for list_ktm in KTP:
  image = cv.imread(list_ktm)                     # read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) # resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  # convert color to RGB

# Menggabungkan 2 gambar
  final_frame = cv.hconcat((image, image_2))      # concatenate image

# Menampilkan gambar menggunakan Matplotlib
  plt.imshow(final_frame)
  plt.axis('off')                                 # hide the axis in the image
  plt.show()

# %%
plt.imshow(ktp)
height_ktp = ktp.shape[0]
width_ktp = ktp.shape[1]
print("resolusi image: tinggi x lebar = ",height_ktp," x ",width_ktp)
# Out:
# resolusi image: tinggi x lebar =  320  x  452

# %%
img = np.copy(ktp_2)

#tutup bagian pekerjaan
for y in range (129,232): #untuk mengatur panjang blok
  for x in range (220,230): #untuk mengatur tinggi blok
    img[x,y] = [0,0,0]

#tutup bagian kewarganegaraan
for y in range (129,150): #untuk mengatur panjang blok
  for x in range (233,243): #untuk mengatur tinggi blok
    img[x,y] = [255,255,255]

final_frame = cv.hconcat((ktp_2, img))
cv2_imshow(final_frame)

plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
plt.axis('on')  # Menampilkan sumbu
plt.show()
# Out:
# <PIL.Image.Image image mode=RGB size=904x320>
